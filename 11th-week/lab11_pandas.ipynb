# %% [markdown]
# # Pandas
# ## freeCodeCamp Survey
# - 정형 데이터 처리

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('fcc-new-coder-survey-2016.csv')
type(df) # create a DataFrame object
# Out:
# /var/folders/ff/jyj5vny502lb6806bc1v_3b40000gn/T/ipykernel_19371/3829700219.py:1: DtypeWarning: Columns (0: CodeEventOther, 1: JobRoleInterestOther) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('fcc-new-coder-survey-2016.csv')
# pandas.DataFrame

# %%
# basic attributes and methods
# df
# df[['SchoolMajor', 'Age']][:10]
# df.columns
# df.index # the index of the rows
# df.dtypes # the data type of each column. str이 obj로 나오는 경우도 있음.
# df.info()
# df.head(10)
# df.tail() # the last 5 rows
df.sample(5) # randomly show 5 rows

# NaN: Not a Number
# NA or ,, => entered no value
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 2388    NaN               0.0             NaN                   NaN
# 9486    NaN               0.0             NaN                   NaN
# 3783   21.0               0.0             NaN                   NaN
# 1400   37.0               0.0             NaN                   NaN
# 10205  43.0               0.0             NaN                   NaN
#
#        BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 2388                 NaN                NaN          NaN                 NaN
# 9486                 NaN                NaN          NaN                 NaN
# 3783                 NaN                NaN          NaN                 NaN
# 1400                 NaN                NaN          NaN                 NaN
# 10205                NaN                NaN          NaN                 NaN
#
#        BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 2388                 NaN             NaN  ...               NaN
# 9486                 NaN             NaN  ...               NaN
# 3783                 NaN             NaN  ...               NaN
# 1400                 NaN             NaN  ...               NaN
# 10205                NaN             NaN  ...               NaN
#
#        ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  \
# 2388                     NaN                NaN              1.0
# 9486                     NaN                NaN              NaN
# 3783                     NaN                NaN              NaN
# 1400                     NaN                NaN              NaN
# 10205                    NaN                NaN              1.0
#
#        ResourceUdemy  ResourceW3Schools  ResourceYouTube  \
# 2388             NaN                NaN              NaN
# 9486             NaN                NaN              NaN
# 3783             NaN                NaN              NaN
# 1400             NaN                NaN              NaN
# 10205            NaN                NaN              NaN
#
#                                   SchoolDegree              SchoolMajor  \
# 2388                                       NaN                      NaN
# 9486                                       NaN                      NaN
# 3783                        associate's degree  Business Administration
# 1400   professional degree (MBA, MD, JD, etc.)      Clinical Psychology
# 10205                        bachelor's degree             Anthropology
#
#        StudentDebtOwe
# 2388              NaN
# 9486              NaN
# 3783              NaN
# 1400              NaN
# 10205             NaN
#
# [5 rows x 113 columns]

# %%
# select columns
# each column is a series
language = df.LanguageAtHome
print(type(language))
print(len(language))
print(language.unique())
# Out:
# <class 'pandas.Series'>
# 15620
# <StringArray>
# [                  'English',                     'Khmer',
#           'Mandarin Chinese',                    'Telugu',
#                    'Bengali',                   'Russian',
#             'Serbo-Croatian',                     'Hindi',
#                    'Spanish',                'Portuguese',
#  ...
#  'Wu (Shanghainese) Chinese',                     'Wolof',
#                    'Quechua',                     'Irish',
#                     'Divehi',                     'Welsh',
#                   'Acehnese',                   'Sylheti',
#                'Eastern Min',                 'Sundanese']
# Length: 149, dtype: str

# %%
language = df['LanguageAtHome']
print(type(language))
print(len(language))
print(language.unique())
# Out:
# <class 'pandas.Series'>
# 15620
# <StringArray>
# [                  'English',                     'Khmer',
#           'Mandarin Chinese',                    'Telugu',
#                    'Bengali',                   'Russian',
#             'Serbo-Croatian',                     'Hindi',
#                    'Spanish',                'Portuguese',
#  ...
#  'Wu (Shanghainese) Chinese',                     'Wolof',
#                    'Quechua',                     'Irish',
#                     'Divehi',                     'Welsh',
#                   'Acehnese',                   'Sylheti',
#                'Eastern Min',                 'Sundanese']
# Length: 149, dtype: str

# %%
columns = df[['LanguageAtHome', 'CountryLive']]
print(type(columns)) # column 두개 이상부터는 테이블이므로 data frame이다.
columns
# Out:
# <class 'pandas.DataFrame'>
#       LanguageAtHome               CountryLive
# 0            English  United States of America
# 1            English  United States of America
# 2            English  United States of America
# 3            English  United States of America
# 4              Khmer  United States of America
# ...              ...                       ...
# 15615        English  United States of America
# 15616        English                    Canada
# 15617        English  United States of America
# 15618        English                    Canada
# 15619        English              South Africa
#
# [15620 rows x 2 columns]

# %% [markdown]
# ## Analysis with plots

# %%
age = df['Age']
ax = age.hist(bins=20, edgecolor='k')
ax.set(xlabel='age', ylabel='counts')
ax.set_title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')
